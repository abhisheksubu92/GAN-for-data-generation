# %%
import psutil ; print(list(psutil.virtual_memory())[0:2])

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import xgboost as xgb

import pickle

import gc
gc.collect()
print(list(psutil.virtual_memory())[0:2])
# Out:
# [8589934592, 1805275136]
# [8589934592, 1762811904]

# %%
import GAN_171103
import importlib
importlib.reload(GAN_171103) # For reloading after making changes
from GAN_171103 import *
# Out:
# /Users/abhisheksubramanian/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
a = np.random.normal(size=1000)
b = np.random.normal(size=1000)
c =  np.random.normal(size = 1000)

# %%
df = pd.DataFrame({'a':a,'b':b,'c':c})

# %%
df.head()
# Out:
#           a         b         c
# 0 -1.281109 -0.024136 -0.788127
# 1 -0.985325  0.564192 -0.461941
# 2  0.357154  0.060562  0.063292
# 3 -0.433342  1.413304 -1.784056
# 4  0.499817  0.922886  1.793930

# %%
rand_dim = 3 # 32 # needs to be ~data_dim
base_n_count = 128 # 128

nb_steps = 5000 + 1 # 50000 # Add one for logging of the last interval
batch_size = 128 # 64

k_d = 1  # number of critic network updates per adversarial training step
k_g = 1  # number of generator network updates per adversarial training step
critic_pre_train_steps = 100 # 100  # number of steps to pre-train the critic before starting adversarial training
log_interval = 100 # 100  # interval (in steps) at which to log loss summaries and save plots of image samples to disc
learning_rate = 5e-4 # 5e-5
data_dir = 'cache/'
generator_model_path, discriminator_model_path, loss_pickle_path = None, None, None

# show = False
show = True 
arguments = [rand_dim, nb_steps, batch_size, 
             k_d, k_g, critic_pre_train_steps, log_interval, learning_rate, base_n_count,
            data_dir, generator_model_path, discriminator_model_path, loss_pickle_path, show ]

# %%
data_cols = [ i for i in df.columns]
# df[ data_cols ] = train[ data_cols ] / 10 # scale to random noise size, one less thing to learn
train_no_label = df[ data_cols ]

# %%
adversarial_training_GAN(arguments, train_no_label, data_cols )
# Out:
# data_dim:  3
# data_cols:  ['a', 'b', 'c']
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               512
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_19 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 166,659
# Trainable params: 166,659
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               2048
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_23 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 166,401
# Trainable params: 0
# Non-trainable params: 166,401
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# generator (Model)            (None, 3)                 166659
# _________________________________________________________________
# discriminator (Model)        (None, 1)                 166401
# =================================================================
# Total params: 333,060
# Trainable params: 166,659
# Non-trainable params: 166,401
# _________________________________________________________________
# None
# Step: 0 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6843, 0.7041, 0.6578, 0.9797
# D Real - D Gen: -0.0462
# Step: 100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.5394, 1.1339, 0.6673, 0.7622
# D Real - D Gen: -0.4665
# Step: 200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6992, 0.7752, 0.6069, 0.7033
# D Real - D Gen: -0.1684
# Step: 300 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6100, 0.9545, 0.6962, 0.6992
# D Real - D Gen: -0.2583
# Step: 400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7684, 0.7190, 0.7065, 0.6179
# D Real - D Gen: -0.0124
# Step: 500 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6992, 0.7357, 0.6976, 0.6626
# D Real - D Gen: -0.0381
# Step: 600 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6830, 0.7420, 0.6785, 0.6301
# D Real - D Gen: -0.0635
# Step: 700 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7936, 0.6319, 0.7240, 0.6585
# D Real - D Gen: 0.0921
# Step: 800 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7703, 0.6640, 0.7243, 0.6850
# D Real - D Gen: 0.0603
# Step: 900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7444, 0.6744, 0.7287, 0.6646
# D Real - D Gen: 0.0544
# Step: 1000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7255, 0.7157, 0.6580, 0.6585
# D Real - D Gen: -0.0577
# Step: 1100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7687, 0.6490, 0.7546, 0.5793
# D Real - D Gen: 0.1056
# Step: 1200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7130, 0.6903, 0.7201, 0.6260
# D Real - D Gen: 0.0297
# Step: 1300 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7364, 0.6738, 0.7019, 0.6118
# D Real - D Gen: 0.0282
# Step: 1400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7490, 0.6936, 0.7218, 0.5915
# D Real - D Gen: 0.0283
# Step: 1500 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7045, 0.7066, 0.6833, 0.5671
# D Real - D Gen: -0.0233
# Step: 1600 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7464, 0.6821, 0.7261, 0.6911
# D Real - D Gen: 0.0440
# Step: 1700 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7225, 0.6733, 0.7168, 0.6199
# D Real - D Gen: 0.0434
# Step: 1800 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6913, 0.7277, 0.6885, 0.6707
# D Real - D Gen: -0.0392
# Step: 1900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6526, 0.8063, 0.6508, 0.6220
# D Real - D Gen: -0.1554
# Step: 2000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7111, 0.7896, 0.7232, 0.5549
# D Real - D Gen: -0.0664
# Step: 2100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7446, 0.6688, 0.7315, 0.6301
# D Real - D Gen: 0.0627
# Step: 2200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6999, 0.7114, 0.6951, 0.6850
# D Real - D Gen: -0.0163
# Step: 2300 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.8530, 0.5962, 0.6757, 0.7073
# D Real - D Gen: 0.0795
# Step: 2400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7078, 0.7032, 0.7144, 0.6402
# D Real - D Gen: 0.0112
# Step: 2500 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7096, 0.7086, 0.7089, 0.6992
# D Real - D Gen: 0.0004
# Step: 2600 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6978, 0.6964, 0.6907, 0.6098
# D Real - D Gen: -0.0057
# Step: 2700 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.8009, 0.6549, 0.6924, 0.6789
# D Real - D Gen: 0.0375
# Step: 2800 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7031, 0.7033, 0.6528, 0.6301
# D Real - D Gen: -0.0505
# Step: 2900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7631, 0.6663, 0.7252, 0.6524
# D Real - D Gen: 0.0589
# Step: 3000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6107, 0.8372, 0.6360, 0.6179
# D Real - D Gen: -0.2013
# Step: 3100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6971, 0.7367, 0.7026, 0.6199
# D Real - D Gen: -0.0341
# Step: 3200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6995, 0.7076, 0.7266, 0.6321
# D Real - D Gen: 0.0191
# Step: 3300 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7348, 0.6728, 0.7149, 0.6565
# D Real - D Gen: 0.0421
# Step: 3400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6213, 0.8302, 0.6555, 0.6789
# D Real - D Gen: -0.1748
# Step: 3500 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7642, 0.6626, 0.7162, 0.6829
# D Real - D Gen: 0.0536
# Step: 3600 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7521, 0.6578, 0.7208, 0.5630
# D Real - D Gen: 0.0630
# Step: 3700 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7479, 0.6734, 0.6767, 0.6159
# D Real - D Gen: 0.0034
# Step: 3800 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6845, 0.7157, 0.6990, 0.5528
# D Real - D Gen: -0.0167
# Step: 3900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7049, 0.6861, 0.6861, 0.6321
# D Real - D Gen: 0.0001
# Step: 4000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6761, 0.7352, 0.6440, 0.6687
# D Real - D Gen: -0.0912
# Step: 4100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7244, 0.6827, 0.6996, 0.6687
# D Real - D Gen: 0.0169
# Step: 4200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6507, 0.7665, 0.6653, 0.6301
# D Real - D Gen: -0.1012
# Step: 4300 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6433, 0.7773, 0.6568, 0.7358
# D Real - D Gen: -0.1204
# Step: 4400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7041, 0.6949, 0.6934, 0.6707
# D Real - D Gen: -0.0015
# Step: 4500 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7306, 0.6756, 0.7166, 0.6829
# D Real - D Gen: 0.0411
# Step: 4600 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6816, 0.7139, 0.6778, 0.6585
# D Real - D Gen: -0.0360
# Step: 4700 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6753, 0.7902, 0.7070, 0.7256
# D Real - D Gen: -0.0832
# Step: 4800 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7316, 0.6641, 0.7113, 0.6098
# D Real - D Gen: 0.0472
# Step: 4900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7175, 0.6801, 0.6999, 0.6382
# D Real - D Gen: 0.0198
# Step: 5000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.6698, 0.7350, 0.6981, 0.7134
# D Real - D Gen: -0.0369

# %%
adversarial_training_WGAN(arguments, train_no_label, data_cols=data_cols )
# Out:
# data_dim:  3
# data_cols:  ['a', 'b', 'c']
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               512
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_28 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 166,659
# Trainable params: 166,659
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# dense_29 (Dense)             (None, 512)               2048
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_31 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 166,401
# Trainable params: 0
# Non-trainable params: 166,401
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# generator (Model)            multiple                  166659
# _________________________________________________________________
# discriminator (Model)        multiple                  166401
# =================================================================
# Total params: 333,060
# Trainable params: 166,659
# Non-trainable params: 166,401
# _________________________________________________________________
# None
# pre-training the critic...
# Step: 0 of 100 critic pre-training.
# Step: 20 of 100 critic pre-training.
# Step: 40 of 100 critic pre-training.
# Step: 60 of 100 critic pre-training.
# Step: 80 of 100 critic pre-training.
# Last batch of critic pre-training disc_loss: (-0.19816749, -0.090923116).
# Step: 0 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1992, -0.2000, -0.0999, 0.9858
# D Real - D Gen: 0.1002
# Step: 100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1230, -0.1088, -0.2025, 0.9634
# D Real - D Gen: -0.0936
# Step: 200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0506, -0.0277, 0.0184, 0.9167
# D Real - D Gen: 0.0462
# Step: 300 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0343, 0.0365, 0.0906, 0.9512
# D Real - D Gen: 0.0541
# Step: 400 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0405, 0.0422, 0.0248, 0.8699
# D Real - D Gen: -0.0174
# Step: 500 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0440, 0.0475, 0.1674, 0.9146
# D Real - D Gen: 0.1200
# Step: 600 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.1230, 0.1535, 0.1401, 0.8882
# D Real - D Gen: -0.0133
# Step: 700 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0382, 0.0263, 0.0408, 0.8313
# D Real - D Gen: 0.0145
# Step: 800 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0557, 0.1512, 0.0680, 0.9126
# D Real - D Gen: -0.0832
# Step: 900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1023, -0.0783, -0.0763, 0.7134
# D Real - D Gen: 0.0020
# Step: 1000 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0505, 0.0405, 0.0964, 0.7541
# D Real - D Gen: 0.0560
# Step: 1100 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.2366, 0.2142, 0.1911, 0.7967
# D Real - D Gen: -0.0231
# Step: 1200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0303, 0.0351, 0.1055, 0.9715
# D Real - D Gen: 0.0704
# Step: 1300 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0224, 0.0801, 0.0361, 0.9654
# D Real - D Gen: -0.0440
# Step: 1400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0766, -0.0715, -0.1505, 0.9065
# D Real - D Gen: -0.0790
# Step: 1500 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.2313, 0.2583, 0.0505, 1.0000
# D Real - D Gen: -0.2078
# Step: 1600 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.2166, 0.3442, 0.1528, 0.9756
# D Real - D Gen: -0.1914
# Step: 1700 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0238, 0.0110, 0.0783, 0.8984
# D Real - D Gen: 0.0674
# Step: 1800 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1885, -0.1736, -0.2115, 0.9593
# D Real - D Gen: -0.0379
# Step: 1900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.8127, -0.8117, -0.8868, 0.9776
# D Real - D Gen: -0.0751
# Step: 2000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 1.1481, -1.1034, -1.1815, 0.9268
# D Real - D Gen: -0.0782
# Step: 2100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 1.6187, -1.5924, -1.6400, 0.9045
# D Real - D Gen: -0.0475
# Step: 2200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 1.4680, -1.4773, -1.5297, 0.7846
# D Real - D Gen: -0.0524
# Step: 2300 of 5001.
# Losses: G, D Gen, D Real, Xgb: 1.2892, -1.3023, -1.3655, 0.9289
# D Real - D Gen: -0.0633
# Step: 2400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 1.0981, -1.0295, -1.0365, 0.8394
# D Real - D Gen: -0.0071
# Step: 2500 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7528, -0.7362, -0.6175, 0.9146
# D Real - D Gen: 0.1186
# Step: 2600 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2873, -0.2852, -0.3480, 0.9187
# D Real - D Gen: -0.0628
# Step: 2700 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2413, -0.2184, -0.2063, 0.8171
# D Real - D Gen: 0.0120
# Step: 2800 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.1293, 0.1451, 0.0295, 0.9533
# D Real - D Gen: -0.1156
# Step: 2900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2259, -0.2118, -0.2261, 0.9207
# D Real - D Gen: -0.0143
# Step: 3000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2205, -0.2248, -0.1963, 0.8476
# D Real - D Gen: 0.0285
# Step: 3100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1352, -0.1239, -0.1917, 0.9614
# D Real - D Gen: -0.0678
# Step: 3200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1370, -0.1075, -0.1611, 0.8841
# D Real - D Gen: -0.0536
# Step: 3300 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2337, -0.2240, -0.2238, 0.9207
# D Real - D Gen: 0.0002
# Step: 3400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2066, -0.1779, -0.2358, 0.8780
# D Real - D Gen: -0.0578
# Step: 3500 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1563, -0.2047, -0.2734, 0.8780
# D Real - D Gen: -0.0687
# Step: 3600 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1848, -0.1801, -0.1616, 0.9126
# D Real - D Gen: 0.0185
# Step: 3700 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1635, -0.1723, -0.1151, 0.8720
# D Real - D Gen: 0.0572
# Step: 3800 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2538, -0.2582, -0.1971, 0.9817
# D Real - D Gen: 0.0610
# Step: 3900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2976, -0.2778, -0.3096, 0.9654
# D Real - D Gen: -0.0318
# Step: 4000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1596, -0.1819, -0.1555, 0.9370
# D Real - D Gen: 0.0264
# Step: 4100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1265, -0.1246, -0.1549, 0.9431
# D Real - D Gen: -0.0304
# Step: 4200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0530, -0.0268, -0.0414, 0.9228
# D Real - D Gen: -0.0146
# Step: 4300 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1663, -0.1634, -0.1698, 0.9350
# D Real - D Gen: -0.0065
# Step: 4400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0295, -0.0538, -0.1081, 0.9533
# D Real - D Gen: -0.0543
# Step: 4500 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.3256, -0.3193, -0.3129, 0.9654
# D Real - D Gen: 0.0064
# Step: 4600 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1517, -0.1444, -0.0621, 0.9939
# D Real - D Gen: 0.0823
# Step: 4700 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0953, -0.0846, -0.0801, 0.9309
# D Real - D Gen: 0.0045
# Step: 4800 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0102, 0.0661, 0.0367, 0.9512
# D Real - D Gen: -0.0294
# Step: 4900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0641, -0.0312, -0.1071, 0.9126
# D Real - D Gen: -0.0760
# Step: 5000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0763, -0.0723, -0.0148, 0.9593
# D Real - D Gen: 0.0576

# %%
rand_dim = 3
base_n_count = 128
model_names = ['GAN','WGAN']
with_classes = [False, True, False, True]
type0s = [None, None, 'Wasserstein', 'Wasserstein']

models = {}

for model_name, with_class, type0 in zip(model_names, with_classes, type0s ):

    if with_class:
        generator_model, discriminator_model, combined_model = \
            define_models_CGAN(rand_dim, data_dim, label_dim, base_n_count, type=type0)
    else:
         generator_model, discriminator_model, combined_model = \
            define_models_GAN(rand_dim, data_dim, base_n_count, type=type0)   
    
    models[model_name] = [ model_name, with_class, type0, generator_model ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-7b67ecb8c868> in <module>()
#      12         generator_model, discriminator_model, combined_model =             define_models_CGAN(rand_dim, data_dim, label_dim, base_n_count, type=type0)
#      13     else:
# ---> 14          generator_model, discriminator_model, combined_model =             define_models_GAN(rand_dim, data_dim, base_n_count, type=type0)
#      15
#      16     models[model_name] = [ model_name, with_class, type0, generator_model ]
#
# NameError: name 'data_dim' is not defined
